# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 70.6 MB/s eta 0:00:00
# ...

# %%
# !unzip "/content/tennis ball detection.v6i.yolov5pytorch.zip" -d "tennis-ball-detection"

# %%
# !yolo task=detect mode=train model=yolov8m.pt data="/content/tennis-ball-detection/data.yaml" epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.197 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
